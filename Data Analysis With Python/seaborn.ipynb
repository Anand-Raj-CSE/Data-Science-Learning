# %%
# !pip install seaborn
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\users\aanan\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...

# %%
import seaborn as sns

# %% [markdown]
# ### Basic plotting with seaborn

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("Scatter plot for tips")
plt.show()

# %%
#Lineplot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Total bill vs size")
plt.show()

# %%
# Categorical plots
#Bar plot
sns.barplot(x='day',y='total_bill',data=tips)
plt.title('Bills acccording to days')
plt.show()

# %%
# Box plot
sns.boxplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
#violin plot
sns.violinplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.histplot(tips['total_bill'],bins=10,kde=True) # kde gives the curve of distribution , kde is kernel density estimator.
plt.show()

# %%
# KDE plot - kernel density estimator
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
# pair plot = we want to campare features then we use this , it only takes features that have numerica value
sns.pairplot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#heatmap
corr= tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
#customization with matplotlib
import pandas as pd

# %%
dataset = pd.read_csv('sales_data.csv')
dataset
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
## Plottotal sales by product
plt.figure(figsize=(10,6))
sns.barplot(x='Product Category',y='Total Revenue',data=dataset,estimator=sum)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Region',y='Total Revenue',data=dataset,estimator=sum)
plt.show()
